# %% [markdown]
# ## Assignment: Elementary Operations on Matrices
# # Task 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 1st picture computing the matrixes and
# finding the elements-wise of the product

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 2nd picture how i calculated the Matrix Product and explaining my findigs which are:
# These observations highlight the non-commutative nature of matrix multiplication and the significance of the order of multiplication in matrix products. On the other hand, element-wise products are commutative, meaning the order of matrices does not affect the result when performing element-wise multiplication.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 3rd picture finding what is B^-1 and multiplied by A^-1 and finding: (BA)^-1= B^-1 A^-1
# and also the conclusion about B, B^-1:
# In summary, the comparison between
#
# B and −B^-1
#
#   illustrates the relationship between a diagonal matrix and its inverse. Diagonal matrices have a unique structure that simplifies the process of finding their inverses, and the product of a diagonal matrix and its inverse yields the identity matrix. This property is fundamental in linear algebra and has various applications in solving systems of linear equations and diagonalizing matrices.
